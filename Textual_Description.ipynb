# %% [markdown]
# ### Import required packages

# %%
# Import statements
import pandas as pd
import numpy as np
import os
import json
from os import path
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Open the corresponding dataset

# %%
#Open corresponding file
filename = "tweets"
file_format = filename+'.csv'
filename = file_format
encoding = ['utf8','latin1','iso-8859-1','cp1252']
flag = False
encoding_list = len(encoding)
if file_format.endswith('.html'):
    dfs = pd.read_html(file_format)
    df  = pd.concat(dfs)
    df.to_csv(filename+".csv",index=False)
if file_format.endswith('.json'):
    df = pd.read_json(filename)
if 'parsed.csv' in filename:
    df = pd.read_csv(file_format, index_col=0 )
    flag = True
if flag != True:
#Try all the possible encoding schemes to see which one applies to the dataset
    for encoding_type in range(0,encoding_list-1):
        try:
            if file_format.endswith('.csv'):
                df = pd.read_csv(file_format, index_col=None , encoding = encoding[encoding_type])
                break
        except Exception:
            pass

# %%
df
# Out:
#                       id           handle  \
# 0     780925634159796224   HillaryClinton
# 1     780916180899037184   HillaryClinton
# 2     780911564857761793   HillaryClinton
# 3     780907038650068994   HillaryClinton
# 4     780897419462602752   HillaryClinton
# ...                  ...              ...
# 6439  684219579548041218  realDonaldTrump
# 6440  684218836569206784  realDonaldTrump
# 6441  684218305100525569  realDonaldTrump
# 6442  684217554861199360  realDonaldTrump
# 6443  684216973815844866  realDonaldTrump
#
#                                                    text  is_retweet  \
# 0     The question in this election: Who can put the...       False
# 1     Last night, Donald Trump said not paying taxes...        True
# 2     Couldn't be more proud of @HillaryClinton. Her...        True
# 3     If we stand together, there's nothing we can't...       False
# 4     Both candidates were asked about how they'd co...       False
# ...

# %% [markdown]
# ### Method to display the column information, null and unique values of the dataset

# %%
def data_info(data):
    
    try:
        #Align column data by converting all column names to lower case and removing empty spaces
        try:
            data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
        except:
            print("The column names are of type numerical")
            pass
        # lists the total values and columns in the dataset
        print("There are {} observations and {} features in this dataset. \n".format(data.shape[0],data.shape[1]))
        print("The list of columns in this dataset are: \n")
        #Lists the number of columns in a datset
        for col in data.columns:    
            print(col)
        print("\n")
        null_counts = data.isnull().sum()
        #Identify if the columns that has a null value
        print("The list of columns that has a null value are depicted as 'True' in the below list:\n{}".format(df.isnull().any()))
        print("\n")
        # Check if the columns are unique which are represented as 'True'
        print("The list of columns that has unique values are indicated as 'True':\n")
        for i in data.columns:
            print('{} is unique: {}'.format(i, data[i].is_unique))
        print("\n")
        #Check the number of null values in each column
        print("Number of null values in each column:\n{}".format(null_counts))
        print("\n")
        print("Total number of null values in the dataset is",null_counts.sum())
        #Prints the data types of the columns in the dataset
        print("\nData types and their frequency:\n{}".format(data.dtypes))
    except ValueError as e:
        print("Value error {} occured".format(e))

# %% [markdown]
# ### Invoke the column information method

# %%
#Prints general info on the dataset
data_info(df)
# Out:
# There are 6444 observations and 28 features in this dataset.
#
# The list of columns in this dataset are:
#
# id
# handle
# text
# is_retweet
# original_author
# time
# in_reply_to_screen_name
# in_reply_to_status_id
# in_reply_to_user_id
# is_quote_status
# lang
# retweet_count
# favorite_count
# longitude
# latitude
# place_id
# place_full_name
# place_name
# place_type
# place_country_code
# place_country
# place_contained_within
# place_attributes
# place_bounding_box
# source_url
# truncated
# entities
# extended_entities
#
#
# The list of columns that has a null value are depicted as 'True' in the below list:
# id                         False
# handle                     False
# text                       False
# is_retweet                 False
# original_author             True
# time                       False
# in_reply_to_screen_name     True
# in_reply_to_status_id       True
# in_reply_to_user_id         True
# is_quote_status            False
# ...
